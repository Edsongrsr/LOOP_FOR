# %% [markdown]
# <a href="https://colab.research.google.com/github/Edsongrsr/LOOP_FOR/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(10):
  print("teste", i)
# Out:
# teste 0
# teste 1
# teste 2
# teste 3
# teste 4
# teste 5
# teste 6
# teste 7
# teste 8
# teste 9

# %%
frutas = ["maca","banana","laranja"]
for item in frutas:
  print(item)
# Out:
# maca
# banana
# laranja

# %%
lista_vendas = [1000,500,800,1500,2000,2300]
for i in lista_vendas:
  print(i)
# Out:
# 1000
# 500
# 800
# 1500
# 2000
# 2300

# %%
#Atividade 01

lista_vendas = [1000,500,800,1500,2000,2300]
meta = 1200
percentual_bonus = 0.1
for venda in lista_vendas:
  if venda >= meta:
       bonus = percentual_bonus * venda
  else:
      bonus=0
  print(bonus)
# Out:
# 0
# 0
# 0
# 150.0
# 200.0
# 230.0

# %%
vendas_diarias = [2000, 3000, 2500, 4000, 1800, 5000, 2700]
meta =
# Out:
# 2

# %%
#Atividade 02

vendas_funcionarios = [2800, 3200, 1500, 4000, 5000, 1000, 3500]
meta = 3000
percentual_bonus = 0.05
for venda in vendas_funcionarios:
  if venda >= meta:
    bonus = percentual_bonus * venda
  else:
     bonus=0
  print(bonus)
# Out:
# 0
# 160.0
# 0
# 200.0
# 250.0
# 0
# 175.0

# %%
vendas_diarias = [2000, 3000, 2500, 4000, 1800, 5000, 2700]
meta=2500
dias = 0
dias_acima_da_meta = 0
for diaria in vendas_diarias:
  if diaria > meta:
    dias_acima_da_meta = dias_acima_da_meta + 1
print(dias_acima_da_meta)
# Out:
# 4

# %%
#Atividade 03

vendas_vendedores = [1500, 2500, 1800, 3200, 4000, 1200, 2800]
meta=2000
percentual_bonus = 0.08
for venda in vendas_funcionarios:
  if venda >= meta:
    bonus = percentual_bonus * venda
  else:
     bonus=0
  print(bonus)
# Out:
# 224.0
# 256.0
# 0
# 320.0
# 400.0
# 0
# 280.0

# %%
#Atividade 04

lista_vendas = [1000, 500, 800, 1500, 2000, 2300]
meta=1200
contador = 0

for venda in lista_vendas:
  if venda > meta:
    #contador = + 1
    contador +=1
print("Quantidade de vendas que atingiram a meta", contador)
# Out:
# Quantidade de vendas que atingiram a meta 3

# %%
#Atividade 05

lista_vendas = [1000, 500, 800, 1500, 2000, 2300]
meta = 1200
percentual_extra=0.1
bonus_extra=50

for venda in lista_vendas:
  bonus = 0

  if venda >= meta:
    bonus = venda * percentual_extra

    if venda >= 2000:
      bonus = bonus + bonus_extra
  print(f"venda:{venda} -> Bonus : R${bonus}")
# Out:
# venda:1000 -> Bonus : R$0
# venda:500 -> Bonus : R$0
# venda:800 -> Bonus : R$0
# venda:1500 -> Bonus : R$150.0
# venda:2000 -> Bonus : R$250.0
# venda:2300 -> Bonus : R$280.0

# %%
#Atividade 06

lista_vendas = [1000, 500, 800, 1500, 2000, 2300]
maior_vendas = lista_vendas[0]

for venda in lista_vendas:
  if venda > maior_vendas:
    maior_vendas = venda
print("A maior venda", maior_vendas)
# Out:
# A maior venda 2300
